# %% [markdown]
# <a href="https://colab.research.google.com/github/Artist42/Artist42.github.io/blob/main/demos/PixelDrawer_Init_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pixray PixelDraw demo
# Using pixray to draw pixel art.
#
# ![shark.png](data:image/png;base64,...)
# <br>
# A synthwave great white shark by <a href="https://twitter.com/ViktorAlm">Viktor Alm</a>
